# %% [markdown]
# <a href="https://colab.research.google.com/github/Devanbagh0711/DA_projects/blob/main/project_explations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !apt.get install sqlite3
# !pip install pandas
# Out:
# /bin/bash: line 1: apt.get: command not found
# ...

# %%
import sqlite3
import pandas as pd
import os

# %%
conn = sqlite3.connect("my_database_db")

# %%
#define file path
db_path=("/content/drive/MyDrive/Colab Notebooks/my_database (8).db")

# %%
df_folder =("/content/drive/MyDrive/Colab Notebooks/SQL folder created")

db_path = os.path.join(df_folder,"my_database_db")
os.makedirs(df_folder,exist_ok=True)

conn = sqlite3.connect(db_path)
cursor = conn.cursor()

print("database connected at:",db_path)
# Out:
# database connected at: /content/drive/MyDrive/Colab Notebooks/SQL folder created/my_database_db

# %%
cursor.execute('''

CREATE TABLE CUSTOMER ( customer_id INT ,
             	customer_name VARCHAR(20),
             	Address VARCHAR(20),
             	State VARCHAR(20),
             	Telephone VARCHAR(10));
''')
conn.commit()

# %%
def insert_CUSTOMER (customer_id,customer_name,Address,state,Telephone):
    cursor.execute('''INSERT INTO CUSTOMER (customer_id,customer_name,Address,state,Telephone) VALUES (?,?, ?, ?,?)''', (customer_id,customer_name,Address,state,Telephone))
    conn.commit()

# %%
insert_CUSTOMER (123001,"Oliver", "225-5, Emeryville", "CA" , "1897614500")
insert_CUSTOMER (123002,"George", "194-6,New brighton","MN" , "1897617000")

# %%
pip install tabulate
# Out:
# ...
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 447, in run
#     conflicts = self._determine_conflicts(to_install)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 578, in _determine_conflicts
#     return check_install_conflicts(to_install)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/operations/check.py", line 101, in check_install_conflicts
# ...

# %%
from tabulate import tabulate

# %%
#fetc data
cursor.execute("SELECT * FROM CUSTOMER")

rows = cursor.fetchall()

column_namez =[desc[0]  for desc in cursor.description]

print(tabulate(rows,headers=column_namez,tablefmt="grid"))
# Out:
# +---------------+-----------------+--------------------+---------+-------------+
# |   customer_id | customer_name   | Address            | State   |   Telephone |
# +===============+=================+====================+=========+=============+
# |        123001 | Oliver          | 225-5, Emeryville  | CA      |  1897614500 |
# +---------------+-----------------+--------------------+---------+-------------+
# |        123002 | George          | 194-6,New brighton | MN      |  1897617000 |
# +---------------+-----------------+--------------------+---------+-------------+
